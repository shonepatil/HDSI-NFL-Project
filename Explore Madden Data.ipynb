# %%
import numpy as np
import pandas as pd
import math

# Read csv into pandas dataframe
df = pd.read_csv('nfl_ratings_17.csv', low_memory=False)
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#       Unnamed: 0             name team position  awareness  throw power  \
# 0              0     kylejuszczyk   SF       RB         85           35
# 1              1    navorrobowman   SF       LB         90           22
# 2              2     pierregarcon   SF       WR         92           35
# 3              3    elvisdumervil   SF       DE         91           34
# 4              4       carloshyde   SF       RB         84           35
# ...          ...              ...  ...      ...        ...          ...
# 2489        2489          ryanbee  DET       DE         71           22
# 2490        2490  khariblasingame  TEN       RB         72           31
# 2491        2491     charlesjones  JAX       TE         68           31
# 2492        2492      donaldpayne  HST       LB         69           25
# 2493        2493         jayajayi  MIA       RB         72           31
#
#       kick return  strength  ball carrier vision  catch in traffic  \
# ...

# %%
data = pd.read_csv('train_fixed.csv', low_memory=False)

# %%
data
# Out:
#         Unnamed: 0      GameId          PlayId  Team      X      Y     S  \
# 0                0  2017090700  20170907000118  away  73.91  34.84  1.69
# 1                1  2017090700  20170907000118  away  74.67  32.64  0.42
# 2                2  2017090700  20170907000118  away  74.00  33.20  1.22
# 3                3  2017090700  20170907000118  away  71.46  27.70  0.42
# 4                4  2017090700  20170907000118  away  69.32  35.42  1.82
# ...            ...         ...             ...   ...    ...    ...   ...
# 509757      509757  2018123015  20181230154157  home  86.77  24.20  2.14
# 509758      509758  2018123015  20181230154157  home  86.76  27.18  1.16
# 509759      509759  2018123015  20181230154157  home  87.26  27.05  2.59
# 509760      509760  2018123015  20181230154157  home  84.57  24.37  4.36
# 509761      509761  2018123015  20181230154157  home  80.80  26.35  4.87
#
#            A   Dis  Orientation     Dir    NflId      DisplayName  \
# ...
